# %%
import pandas as pd
import numpy as np

# %%
rating_cols = ['user_id', 'movie_id', 'rating']
ratings = pd.read_csv('u.data', sep='\t', names=rating_cols, usecols=[0, 1, 2], encoding="ISO-8859-1")

# %%
movie_cols = ['movie_id', 'title']
movies = pd.read_csv('u.item', sep='|', names=movie_cols, usecols=[0, 1], encoding="ISO-8859-1")

# %%
ratings = pd.merge(movies, ratings)

# %%
ratings.head()
# Out:
#    movie_id             title  user_id  rating
# 0         1  Toy Story (1995)      308       4
# 1         1  Toy Story (1995)      287       5
# 2         1  Toy Story (1995)      148       4
# 3         1  Toy Story (1995)      280       4
# 4         1  Toy Story (1995)       66       3

# %%
movieRatings = ratings.pivot_table(index=['user_id'],columns=['title'],values='rating') #pivot_table function to construct a user/movie rating matrix.
movieRatings.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
# 5                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
starWarsRatings = movieRatings['Star Wars (1977)'] #users who rated Star Wars.
starWarsRatings.head()
# Out:
# user_id
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# 5    4.0
# Name: Star Wars (1977), dtype: float64

# %%
AngryMenRatings = movieRatings['12 Angry Men (1957)'] #users who rated Angry Men.
AngryMenRatings .head()
# Out:
# user_id
# 1    5.0
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# Name: 12 Angry Men (1957), dtype: float64

# %%
similarMovies = movieRatings.corrwith(starWarsRatings) # pairwise correlation of Star Wars vector of user rating with every other movie
similarMovies = similarMovies.dropna() # Drop results that have no data
df = pd.DataFrame(similarMovies) # new Dataframe of movies and their correlation score to Star Wars
df.head(10)
# Out:
#                                             0
# title
# 'Til There Was You (1997)            0.872872
# 1-900 (1994)                        -0.645497
# 101 Dalmatians (1996)                0.211132
# 12 Angry Men (1957)                  0.184289
# 187 (1997)                           0.027398
# 2 Days in the Valley (1996)          0.066654
# 20,000 Leagues Under the Sea (1954)  0.289768
# 2001: A Space Odyssey (1968)         0.230884
# 39 Steps, The (1935)                 0.106453
# 8 1/2 (1963)                        -0.142977

# %%
similarMovies_1 = movieRatings.corrwith(AngryMenRatings) # pairwise correlation of  Angry Men vector of user rating with every other movie
similarMovies_1 = similarMovies_1.dropna() # Drop  results that have no data
df_1 = pd.DataFrame(similarMovies_1) #  new Dataframe of movies and their correlation score to Angry Men
df_1.head(10)
# Out:
#                                             0
# title
# 'Til There Was You (1997)           -0.500000
# 101 Dalmatians (1996)               -0.049890
# 12 Angry Men (1957)                  1.000000
# 187 (1997)                           0.666667
# 2 Days in the Valley (1996)          0.256625
# 20,000 Leagues Under the Sea (1954)  0.274772
# 2001: A Space Odyssey (1968)         0.178848
# 39 Steps, The (1935)                 0.457176
# 8 1/2 (1963)                         0.635698
# Above the Rim (1994)                 1.000000

# %%
similarMovies_1.sort_values(ascending=False) #Sort the results by similarity score.
# Out:
# title
# Spirits of the Dead (Tre passi nel delirio) (1968)          1.000000
# Jefferson in Paris (1995)                                   1.000000
# Double Happiness (1994)                                     1.000000
# Nina Takes a Lover (1994)                                   1.000000
# Dream With the Fishes (1997)                                1.000000
# Run of the Country, The (1995)                              1.000000
# Screamers (1995)                                            1.000000
# Pyromaniac's Love Story, A (1995)                           1.000000
# FairyTale: A True Story (1997)                              1.000000
# Stalker (1979)                                              1.000000
# Bad Moon (1996)                                             1.000000
# Surviving Picasso (1996)                                    1.000000
# The Innocent (1994)                                         1.000000
# ...

# %%
similarMovies.sort_values(ascending=False)
# Out:
# title
# No Escape (1994)                                                                     1.000000
# Man of the Year (1995)                                                               1.000000
# Hollow Reed (1996)                                                                   1.000000
# Commandments (1997)                                                                  1.000000
# Cosi (1996)                                                                          1.000000
# Stripes (1981)                                                                       1.000000
# Golden Earrings (1947)                                                               1.000000
# Mondo (1996)                                                                         1.000000
# Line King: Al Hirschfeld, The (1996)                                                 1.000000
# Outlaw, The (1943)                                                                   1.000000
# ...

# %%
movieStats = ratings.groupby('title').agg({'rating': [np.size, np.mean]})

# %%
movieStats.head()
# Out:
#                           rating
#                             size      mean
# title
# 'Til There Was You (1997)      9  2.333333
# 1-900 (1994)                   5  2.600000
# 101 Dalmatians (1996)        109  2.908257
# 12 Angry Men (1957)          125  4.344000
# 187 (1997)                    41  3.024390

# %%
popularMovies = movieStats['rating']['size'] >= 100 # Ignore movies rated by less than 100 people
movieStats[popularMovies].sort_values([('rating', 'mean')], ascending=False)[:20]
# Out:
#                                                    rating
#                                                      size      mean
# title
# Close Shave, A (1995)                                 112  4.491071
# Schindler's List (1993)                               298  4.466443
# Wrong Trousers, The (1993)                            118  4.466102
# Casablanca (1942)                                     243  4.456790
# Shawshank Redemption, The (1994)                      283  4.445230
# Rear Window (1954)                                    209  4.387560
# Usual Suspects, The (1995)                            267  4.385768
# Star Wars (1977)                                      583  4.358491
# 12 Angry Men (1957)                                   125  4.344000
# Citizen Kane (1941)                                   198  4.292929
# To Kill a Mockingbird (1962)                          219  4.292237
# One Flew Over the Cuckoo's Nest (1975)                264  4.291667
# ...

# %%
df = movieStats[popularMovies].join(pd.DataFrame(similarMovies, columns=['similarity']))

# %%
df.sort_values(['similarity'], ascending=False)[:20]
# Out:
#                                                     (rating, size)  \
# title
# Star Wars (1977)                                               583
# Empire Strikes Back, The (1980)                                367
# Return of the Jedi (1983)                                      507
# Raiders of the Lost Ark (1981)                                 420
# Austin Powers: International Man of Mystery (1997)             130
# Sting, The (1973)                                              241
# Indiana Jones and the Last Crusade (1989)                      331
# Pinocchio (1940)                                               101
# Frighteners, The (1996)                                        115
# L.A. Confidential (1997)                                       297
# Wag the Dog (1997)                                             137
# Dumbo (1941)                                                   123
# Bridge on the River Kwai, The (1957)                           165
# ...

# %%
df.sort_values(['similarity'], ascending=False)[:3] #Therefore, we get all the Star Wars related movie as the top 3 entries.
# Out:
#                                  (rating, size)  (rating, mean)  similarity
# title
# Star Wars (1977)                            583        4.358491    1.000000
# Empire Strikes Back, The (1980)             367        4.204360    0.747981
# Return of the Jedi (1983)                   507        4.007890    0.672556
